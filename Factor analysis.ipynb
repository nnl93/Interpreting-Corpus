# %%
import pandas as pd
import csv
from factor_analyzer import FactorAnalyzer
df=pd.read_csv("/users/nannanliu/Research/MD/MD Chinese.csv", quoting=csv.QUOTE_NONE)

# %%
df
# Out:
#            features    AMP   ANDC   AWL     BE  BYPA  CAUS  CONC  COND  \
# 0         reportage   7.19  16.13  1.64   9.59  1.72  2.09  0.56  0.77
# 1        editorials   8.49  15.80  1.63  14.88  2.58  3.95  0.89  1.91
# 2           reviews   8.74  19.39  1.59  14.67  2.17  3.90  0.89  0.91
# 3          religion   8.30  16.10  1.44  16.05  2.56  6.77  0.65  1.77
# 4            skills  10.91  15.22  1.56  10.76  1.09  6.44  0.30  2.12
# 5           popular  11.15  11.66  1.47  16.08  2.50  3.96  0.72  2.09
# 6       biographies  11.81  12.22  1.46  14.23  2.19  5.14  0.98  1.26
# 7          official   3.35  25.50  1.73   2.81  0.41  0.62  0.03  0.06
# 8          academic   7.40  26.99  1.65  10.92  1.97  5.17  0.55  0.78
# 9   general_fiction  11.51   7.04  1.41  18.02  1.93  3.10  0.70  1.37
# 10  mystery_fiction  12.49   6.27  1.36  14.43  2.54  2.96  0.63  1.14
# 11           sci_fi   8.65   9.19  1.44  11.64  3.06  2.86  0.68  0.61
# ...

# %%
df.columns
# Out:
# Index(['features', 'AMP', 'ANDC', 'AWL', 'BE', 'BYPA', 'CAUS', 'CONC', 'COND',
#        'CONJ_OSUB', 'abbreviations', 'DEMP', 'DPAR', 'DWNT', 'EMPH', 'EX',
#        'FPP', 'HDG', 'INPR', 'JJ', 'NEMD', 'KEMD', 'MOMD', 'NN', 'NOMZ', 'SPP',
#        'PHC', 'PIN', 'BPIN', 'PLACE', 'PIRV', 'PUBV', 'RB', 'SMP', 'negation',
#        'TIME', 'TPP', 'STTR', 'WH', 'classical_functional_words',
#        'classical_syntax', 'disyllabic_words', 'nounnoun', 'light_verb',
#        'verb_reduplication', 'attributive_adjective', 'particles',
#        'classifier', 'modifying_markers', 'disposal_marker', 'PEAS',
#        'Imperfect_aspect', 'onomatopoeia', 'descriptive', 'similie', 'dialect',
#        'idioms', 'english'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 58 columns):
# features                      15 non-null object
# AMP                           15 non-null float64
# ANDC                          15 non-null float64
# AWL                           15 non-null float64
# BE                            15 non-null float64
# BYPA                          15 non-null float64
# CAUS                          15 non-null float64
# CONC                          15 non-null float64
# COND                          15 non-null float64
# CONJ_OSUB                     15 non-null float64
# abbreviations                 15 non-null float64
# DEMP                          15 non-null float64
# DPAR                          15 non-null float64
# DWNT                          15 non-null float64
# EMPH                          15 non-null float64
# EX                            15 non-null float64
# FPP                           15 non-null float64
# ...

# %%
new_df=df.drop(['features'], axis=1)

# %%
new_df
# Out:
#       AMP   ANDC   AWL     BE  BYPA  CAUS  CONC  COND  CONJ_OSUB  \
# 0    7.19  16.13  1.64   9.59  1.72  2.09  0.56  0.77       8.07
# 1    8.49  15.80  1.63  14.88  2.58  3.95  0.89  1.91      12.41
# 2    8.74  19.39  1.59  14.67  2.17  3.90  0.89  0.91      10.97
# 3    8.30  16.10  1.44  16.05  2.56  6.77  0.65  1.77      12.79
# 4   10.91  15.22  1.56  10.76  1.09  6.44  0.30  2.12      10.81
# 5   11.15  11.66  1.47  16.08  2.50  3.96  0.72  2.09      12.10
# 6   11.81  12.22  1.46  14.23  2.19  5.14  0.98  1.26      11.49
# 7    3.35  25.50  1.73   2.81  0.41  0.62  0.03  0.06       4.08
# 8    7.40  26.99  1.65  10.92  1.97  5.17  0.55  0.78       9.41
# 9   11.51   7.04  1.41  18.02  1.93  3.10  0.70  1.37      12.56
# 10  12.49   6.27  1.36  14.43  2.54  2.96  0.63  1.14      11.13
# 11   8.65   9.19  1.44  11.64  3.06  2.86  0.68  0.61      14.43
# 12  11.21   7.29  1.37  14.78  2.57  2.76  0.92  1.75      14.37
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 57 columns):
# AMP                           15 non-null float64
# ANDC                          15 non-null float64
# AWL                           15 non-null float64
# BE                            15 non-null float64
# BYPA                          15 non-null float64
# CAUS                          15 non-null float64
# CONC                          15 non-null float64
# COND                          15 non-null float64
# CONJ_OSUB                     15 non-null float64
# abbreviations                 15 non-null float64
# DEMP                          15 non-null float64
# DPAR                          15 non-null float64
# DWNT                          15 non-null float64
# EMPH                          15 non-null float64
# EX                            15 non-null float64
# FPP                           15 non-null float64
# HDG                           15 non-null float64
# ...

# %%
new_df_t=new_df.replace(0,10**-10)

# %%
to_log = ['DPAR', 'SMP', 'verb_reduplication', 'dialect']

# %%
# since the data contains 0, transform it with Ln (x+1)
# apply log(x+1) element-wise to a subset of columns
import numpy as np
to_log = ['DPAR', 'SMP', 'verb_reduplication', 'dialect']
new_df_log = new_df[to_log].applymap(lambda x: np.log(x+1))

# rename columns
new_df_log.columns = 'log_' + new_df_log.columns

# %%
new_df['DPAR']=new_df_log['log_DPAR']
new_df['SMP']=new_df_log['log_SMP']
new_df['verb_reduplication']=new_df_log['log_verb_reduplication']
new_df['dialect']=new_df_log['log_dialect']

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(new_df_t)
chi_square_value, p_value
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/factor_analyzer/factor_analyzer.py:118: RuntimeWarning: divide by zero encountered in log
#   statistic = -np.log(corr_det) * (n - 1 - (2 * p + 5) / 6)
# (-inf, 0.0)

# %%
mean_artist_hotness = data['artist_hotness'].mean(skipna=True)
print (mean_artist_hotness)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-165b1d3e58f7> in <module>()
#       4
#       5 imr = Imputer(missing_values='0', strategy='mean', axis=0)
# ----> 6 imr = imr.fit(new_df.values)
#       7 imputed_data = imr.transform(new_df.values)
#       8 imputed_data
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/preprocessing/imputation.py in fit(self, X, y)
#     167                                                    self.strategy,
# ...

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model=calculate_kmo(new_df)
kmo_model
# Out:
# nan

# %%
fa = FactorAnalyzer(n_factors=7, rotation='promax')
fa.fit(new_df)
# Out:
# FactorAnalyzer(bounds=(0.005, 1), impute='median', is_corr_matrix=False,
#         method='minres', n_factors=7, rotation='promax',
#         rotation_kwargs={}, use_smc=True)

# %%
fa.get_eigenvalues()
# Out:
# (array([ 3.14691579e+01,  7.84210651e+00,  4.89099741e+00,  3.80128358e+00,
#          2.23304596e+00,  2.04852170e+00,  1.70426573e+00,  9.16663926e-01,
#          5.40832478e-01,  4.98844647e-01,  3.74142859e-01,  2.80911776e-01,
#          2.45470223e-01,  1.53755333e-01,  6.29894353e-15,  4.68393908e-15,
#          3.05872470e-15,  2.99527758e-15,  2.59021582e-15,  1.88099230e-15,
#          1.80525847e-15,  1.43558450e-15,  1.38126133e-15,  1.05053967e-15,
#          9.74671047e-16,  9.14287866e-16,  9.01352160e-16,  8.29555231e-16,
#          7.23082229e-16,  6.12311795e-16,  3.25730398e-16,  2.28266728e-16,
#          1.91546511e-16,  3.23387037e-17, -7.92375824e-17, -9.33557503e-17,
#         -2.53235052e-16, -3.10023746e-16, -4.93018787e-16, -5.25493508e-16,
#         -5.76722760e-16, -7.30648923e-16, -7.86079874e-16, -7.90270252e-16,
#         -1.20928141e-15, -1.34956551e-15, -1.40535273e-15, -1.56188062e-15,
# ...

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

eigvals=[ 3.12708360e+01,  7.79648852e+00,  4.95902017e+00,  3.75930541e+00,
         2.21869848e+00,  2.00336896e+00,  1.77551291e+00,  8.95833169e-01,
         6.75373808e-01,  5.76028052e-01,  4.79095753e-01,  4.13485684e-01,
         3.37288162e-01,  2.94184234e-01,  2.69729197e-01,  2.27948603e-01,
         1.86739944e-01,  1.32968390e-01,  1.15411990e-01,  9.41869550e-02,
         5.33478475e-02,  3.79699318e-02,  1.88466647e-02,  8.50607110e-03,
        -6.89801910e-03, -9.44675141e-03, -4.29494210e-02, -5.01642119e-02,
        -7.10672401e-02, -7.30854757e-02, -1.06765213e-01, -1.33059833e-01,
        -1.42074241e-01, -1.72793346e-01, -1.94190200e-01, -2.08625778e-01,
        -2.31437178e-01, -2.38162430e-01, -2.52816183e-01, -2.58747734e-01,
        -2.95813626e-01, -2.98421194e-01, -3.25530451e-01, -3.29168204e-01,
        -3.59692068e-01, -3.63725581e-01, -3.85060784e-01, -3.89793783e-01,
        -3.96091265e-01, -4.00243010e-01, -4.12114765e-01, -4.21581873e-01,
        -4.29515061e-01, -4.59525397e-01, -4.70102476e-01, -4.78632638e-01,
        -4.89315029e-01]
num_vars=len(eigvals)
fig = plt.figure(figsize=(8,5))
sing_vals = np.arange(num_vars) + 1
plt.plot(sing_vals, eigvals, 'ro-', linewidth=2)
plt.xticks(np.arange(1, num_vars+1, 1.0))
plt.title('Scree Plot')
plt.xlabel('Factor Number')
plt.ylabel('Eigenvalue')
plt.show()

# %%
len(fa.get_eigenvalues())
# Out:
# 2

# %%
type(fa.loadings_)
# Out:
# numpy.ndarray

# %%
fa.loadings_
# Out:
# array([[ 7.33662460e-01, -3.59050375e-02,  1.80134859e-01,
#          3.96799855e-01, -3.79671051e-02, -1.96826245e-01,
#          9.25027964e-02],
#        [-6.55930336e-01, -1.98750899e-01,  1.78894628e-01,
#         -2.14001455e-01,  1.99269684e-01,  1.28607440e-01,
#          1.87318482e-01],
#        [-5.23590723e-01, -5.03862978e-01,  5.11466510e-02,
#         -1.67922174e-01, -7.66231027e-02, -1.98786762e-01,
#          1.47381407e-02],
#        [ 8.44928351e-01, -2.64941125e-01,  4.08214139e-01,
#          1.02152552e-01, -1.31849163e-01,  1.33795114e-01,
#          9.67451882e-02],
#        [ 1.61181460e-01,  3.05023054e-01,  6.37390518e-01,
#         -2.60064125e-01, -1.72834941e-01,  7.93198916e-02,
#         -1.97602075e-01],
#        [ 1.07304107e-01, -3.84935832e-01,  5.48391426e-01,
#          4.28461341e-01,  2.77721255e-01,  3.92703156e-01,
#          1.02558752e-02],
#        [-2.03718431e-02,  6.52664288e-02,  7.69926091e-01,
# ...

# %%
fa.loadings_.tofile('/users/nannanliu/Python/SCIPPC/factor_loadings.csv', sep="", format="%s")

# %%
factor_loadings=[",".join(item) for item in fa.loadings_.astype(str)]

# %%
import  csv

with open("/users/nannanliu/Python/SCIPPC/factor_loadings.csv","w") as f:
    wr = csv.writer(f,delimiter="\n")
    wr.writerow(factor_loadings)

# %%
with open('/users/nannanliu/Python/SCIPPC/factor_loadings.csv', "w") as f:
    writer = csv.writer(f)

# %%
fa.get_communalities()
# Out:
# array([0.66997606, 0.94402889, 0.78491034, 0.51692026, 0.77251606,
#        0.88630033, 0.64861847, 0.66534524, 0.62064505, 0.55295902,
#        0.70989932, 0.90277213, 0.47738495, 0.40036117, 0.64062737,
#        1.09094842, 1.08681363, 0.99500439, 0.80843833, 1.05733812,
#        0.52176267, 1.04351147, 0.93495357, 0.69941207, 1.14521105,
#        0.88651019, 1.07778644, 0.95565008, 0.46678664, 1.00623943,
#        0.83520008, 0.76215419, 0.69310699, 0.98560415, 0.16655877,
#        0.8238735 , 0.33208111, 0.84676858, 1.15348826, 0.90518301,
#        0.75928622, 0.72491846, 0.90878269, 0.53166054, 0.59284516,
#        1.07445863, 0.79022533, 1.16298439, 0.06397006, 0.94426244,
#        0.75906142, 0.64189786, 0.71695747, 0.63314337, 0.1644912 ,
#        0.37028252, 0.42823175])

# %%
fa.get_eigenvalues()
# Out:
# (array([ 3.14691579e+01,  7.84210651e+00,  4.89099741e+00,  3.80128358e+00,
#          2.23304596e+00,  2.04852170e+00,  1.70426573e+00,  9.16663926e-01,
#          5.40832478e-01,  4.98844647e-01,  3.74142859e-01,  2.80911776e-01,
#          2.45470223e-01,  1.53755333e-01,  6.29894353e-15,  4.68393908e-15,
#          3.05872470e-15,  2.99527758e-15,  2.59021582e-15,  1.88099230e-15,
#          1.80525847e-15,  1.43558450e-15,  1.38126133e-15,  1.05053967e-15,
#          9.74671047e-16,  9.14287866e-16,  9.01352160e-16,  8.29555231e-16,
#          7.23082229e-16,  6.12311795e-16,  3.25730398e-16,  2.28266728e-16,
#          1.91546511e-16,  3.23387037e-17, -7.92375824e-17, -9.33557503e-17,
#         -2.53235052e-16, -3.10023746e-16, -4.93018787e-16, -5.25493508e-16,
#         -5.76722760e-16, -7.30648923e-16, -7.86079874e-16, -7.90270252e-16,
#         -1.20928141e-15, -1.34956551e-15, -1.40535273e-15, -1.56188062e-15,
# ...

# %%
value = float('3.05417030e+01')
"%f" % value
# Out:
# '30.541703'

# %%
[i for i in l if i >= 1]
# Out:
# [30.541703,
#  7.79339645,
#  4.89078472,
#  3.78974474,
#  2.23266601,
#  2.04466378,
#  1.70275003]
